# %%
# !nvidia-smi
# Out:
# Fri Apr 24 04:45:29 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install -q esm python-dotenv huggingface_hub
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 53.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 MB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 78.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 31.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 82.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 70.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 74.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 56.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 55.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 56.2 MB/s eta 0:00:00
# ...

# %%
import os
from google.colab import userdata
from huggingface_hub import login

os.environ["HF_TOKEN"] = userdata.get("read_token")
login(token=os.environ["HF_TOKEN"])
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.environ["HF_HOME"] = "/content/drive/MyDrive/DeepLearning_final_proj/hf_cache"
os.makedirs(os.environ["HF_HOME"], exist_ok=True)

# %%
# %cd /content/drive/MyDrive/DeepLearning_final_proj
# !python extract_esm3_hidden_layer.py \
    --input_dir  /content/drive/MyDrive/DeepLearning_final_proj/BAHD_structures \
    --output_dir /content/drive/MyDrive/DeepLearning_final_proj/BAHD_lastLayer_embeddings \
    --num_steps 10 \
    --device cuda \
    --id_from parent \
    --skip_existing
# Out:
# /content/drive/MyDrive/DeepLearning_final_proj
# [INFO] Found 334 input file(s) under /content/drive/.shortcut-targets-by-id/14jABzdSZDguq1W11RqsefMbszZSVihcI/BAHD_structures
# [INFO] Loading ESM3 on device=cuda ...
# Fetching 22 files:   0% 0/22 [00:00<?, ?it/s]
# .gitattributes: 1.52kB [00:00, 4.91MB/s]
#
# Fetching 22 files:   5% 1/22 [00:00<00:12,  1.72it/s]
#
# esm3_entry.list: 0.00B [00:00, ?B/s]
#
#
# data/hyperplanes_8bit_58641.npz:   0% 0.00/30.0M [00:00<?, ?B/s]
#
#
#
# data/hyperplanes_8bit_68103.npz:   0% 0.00/34.9M [00:00<?, ?B/s]
#
#
#
#
# 1utn.pdb: 0.00B [00:00, ?B/s]
#
#
#
#
#
# ParentChildTreeFile.txt: 0.00B [00:00, ?B/s]
#
#
#
#
#
#
# config.json: 100% 3.00/3.00 [00:00<00:00, 19.0kB/s]
# Fetching 22 files:  14% 3/22 [00:00<00:03,  4.96it/s]
#
#
#
#
#
# ParentChildTreeFile.txt: 279kB [00:00, 2.78MB/s]
#
#
#
#
# 1utn.pdb: 360kB [00:00, 3.55MB/s]
# entry_list_safety_29026.list: 213kB [00:00, 950kB/s]
#
# esm3_entry.list: 213kB [00:00, 993kB/s]
# ...

# %%
# %cd /content/drive/MyDrive/DeepLearning_final_proj
# !python extract_esm3_hidden_layer.py \
    --input_dir  /content/drive/MyDrive/DeepLearning_final_proj/UGT_structures \
    --output_dir /content/drive/MyDrive/DeepLearning_final_proj/UGT_lastLayer_embeddings \
    --num_steps 10 \
    --device cuda \
    --id_from parent \
    --skip_existing
# Out:
# /content/drive/MyDrive/DeepLearning_final_proj
# [INFO] Found 949 input file(s) under /content/drive/.shortcut-targets-by-id/1oXmY7tBOj_5s2Qn0MwlfliGuf0iO_K8M/UGT_structures
# [INFO] Loading ESM3 on device=cuda ...
# Fetching 22 files:   0% 0/22 [00:00<?, ?it/s]
# data/weights/esm3_function_decoder_v0.pt(…):   0% 0.00/1.30G [00:00<?, ?B/s]
# data/weights/esm3_function_decoder_v0.pt(…):   0% 0.00/1.30G [00:00<?, ?B/s]
# data/weights/esm3_function_decoder_v0.pt(…):   0% 0.00/1.30G [00:00<?, ?B/s]
# data/weights/esm3_function_decoder_v0.pt(…):   0% 0.00/1.30G [00:00<?, ?B/s]
# data/weights/esm3_function_decoder_v0.pt(…):   0% 0.00/1.30G [00:00<?, ?B/s]
# data/weights/esm3_function_decoder_v0.pt(…):   0% 0.00/1.30G [00:01<?, ?B/s]
# data/weights/esm3_function_decoder_v0.pt(…):   0% 0.00/1.30G [00:01<?, ?B/s]
# data/weights/esm3_function_decoder_v0.pt(…):   0% 0.00/1.30G [00:01<?, ?B/s]
# data/weights/esm3_function_decoder_v0.pt(…):   0% 0.00/1.30G [00:01<?, ?B/s]
# ...
